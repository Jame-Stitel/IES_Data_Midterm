# %%
from downloader import WIKIDownloader

downloader = WIKIDownloader()
downloader.get_books_links('https://en.wikipedia.org/wiki/20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction')
downloader.download_books()
downloader.save_dfs()
# Out:
# Successfully initialized WIKI Books Downloader
# Searching for Books-links of on https://en.wikipedia.org/wiki/20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction ...
# Found 34 Books-links
# Downloading all 34 books ...
# title                                         Nineteen Eighty-Four
# Author                                               George Orwell
# Cover artist                                       Michael Kennard
# Country                                             United Kingdom
# Language                                                   English
# Genre            Dystopian, political fiction, social science f...
# Set in                               London, Airstrip One, Oceania
# Publisher        Secker & Warburg\nJune 8, 1949; 70 years ago (...
# Media type                          Print (hardback and paperback)
# Pages                                                          328
# Awards               NPR Top 100 Science Fiction and Fantasy Books
# OCLC                                                     470015866
# Dewey Decimal                                           823.912[1]
# dtype: object
# title                                                 The Ambassadors
# Author                                                    Henry James
# Country                                 United Kingdom, United States
# Language                                                      English
# Genre                                                     Dark Comedy
# Publisher           Methuen & Co., LondonHarper & Brothers, New Yo...
# Publication date             Methuen: 24-Sept-1903Harpers: 6-Nov-1903
# Media type                                             Print (Serial)
# Pages                                        Methuen: 458Harpers: 432
# OCLC                                                           503867
# dtype: object
# title                An American Tragedy
# Author                  Theodore Dreiser
# Country                               US
# Language                         English
# Genre               Crime fictionTragedy
# Publisher               Boni & Liveright
# Publication date       December 17, 1925
# Dewey Decimal                     813.52
# dtype: object
# title                              Brave New World
# Author                               Aldous Huxley
# Cover artist                        Leslie Holland
# Country                             United Kingdom
# Language                                   English
# Genre           Science fiction, dystopian fiction
# Published                   1932 (Chatto & Windus)
# Pages                311 (1932 ed.)63,766 words[1]
# OCLC                                      20156268
# dtype: object
# title                                                        Catch-22
# Author                                                  Joseph Heller
# Cover artist                                            Paul Bacon[1]
# Country                                                 United States
# Language                                                      English
# Genre               Dark comedyAbsurdist fictionSatireWar fictionH...
# Publisher                                            Simon & Schuster
# Publication date                                    November 10, 1961
# Media type                                           Print (hardback)
# Pages                                     453  (1st edition hardback)
# ISBN                .mw-parser-output cite.citation{font-style:inh...
# OCLC                                                         35231812
# Dewey Decimal                                              813/.54 22
# LC Class                                          PS3558.E476 C3 2004
# Followed by                                       Closing Time (1994)
# dtype: object
# title                            The Catcher in the Rye
# Author                                   J. D. Salinger
# Cover artist                  E. Michael Mitchell[1][2]
# Country                                   United States
# Language                                        English
# Genre            Realistic fictionComing-of-age fiction
# Published                                 July 16, 1951
# Publisher                     Little, Brown and Company
# Media type                                        Print
# Pages                                    234 (may vary)
# OCLC                                             287628
# Dewey Decimal                                    813.54
# dtype: object
# title                                  A Clockwork Orange (novel)
# Author                                            Anthony Burgess
# Cover artist                                       Barry Trengove
# Country                                            United Kingdom
# Language                                            EnglishNadsat
# Genre           Science fiction, dystopian fiction, satire, bl...
# Published                            1962 (William Heinemann, UK)
# Media type      Print (hardback & paperback) & audio book (cas...
# Pages           192 pages (hardback edition)  176 pages (paper...
# ISBN            .mw-parser-output cite.citation{font-style:inh...
# OCLC                                                      4205836
# dtype: object
# title                                           The Day of the Locust
# Author                                                 Nathanael West
# Country                                                 United States
# Language                                                      English
# Genre                                                           Novel
# Publisher                                                Random House
# Publication date                                         May 16, 1939
# Media type                               Print (Hardcover, Paperback)
# Pages                                                          238 pp
# ISBN                .mw-parser-output cite.citation{font-style:inh...
# OCLC                                                         22865781
# dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c6a95c660ab0> in <module>
#       3 downloader = WIKIDownloader()
#       4 downloader.get_books_links('https://en.wikipedia.org/wiki/20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction')
# ----> 5 downloader.download_books()
#
# ~/Syncs/OneDrive/Studying/IES FSV UK/Data Processing in Python/Midterm/downloader.py in download_books(self, pause)
#      53             # print(book.characteristics)
#      54             self.books.append(book)
# ---> 55             time.sleep(pause)
#      56         if self._allow_log:
#      57             print(f'Successfully downloaded {len(self.books)} books')
#
# KeyboardInterrupt:

# %% [markdown]
# Downloader for selected wiki books, saves in df
